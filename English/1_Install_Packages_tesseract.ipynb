# %% [markdown]
# # Install packages
#
# After installing *tesseract* on your operating system, we need to install some libraries so we can use it in python:

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    - -------------------------------------- 1.3/39.0 MB 7.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.9/39.0 MB 7.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.5/39.0 MB 7.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/39.0 MB 7.0 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/39.0 MB 7.1 MB/s eta 0:00:05
#    --------- ------------------------------ 8.9/39.0 MB 7.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.2/39.0 MB 7.1 MB/s eta 0:00:05
#    ------------ --------------------------- 11.8/39.0 MB 7.1 MB/s eta 0:00:04
#    ------------- -------------------------- 13.4/39.0 MB 7.1 MB/s eta 0:00:04
#    --------------- ------------------------ 14.7/39.0 MB 7.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.3/39.0 MB 7.1 MB/s eta 0:00:04
# ...

# %%
pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Congratulations!**
#
# Everything should work now!
